# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
root_dir = "/content"

source_dir = "/content/drive/MyDrive"

# %%
# !git clone https://github.com/Zj-BinXia/BBCU.git
# !git clone https://github.com/XPixelGroup/BasicSR.git
# Out:
# Cloning into 'BBCU'...
# remote: Enumerating objects: 452, done.
# remote: Counting objects: 100% (452/452), done.
# remote: Compressing objects: 100% (394/394), done.
# remote: Total 452 (delta 43), reused 430 (delta 38), pack-reused 0
# Receiving objects: 100% (452/452), 15.00 MiB | 16.95 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Cloning into 'BasicSR'...
# remote: Enumerating objects: 5919, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 5919 (delta 4), reused 8 (delta 2), pack-reused 5902
# Receiving objects: 100% (5919/5919), 4.16 MiB | 17.74 MiB/s, done.
# Resolving deltas: 100% (3733/3733), done.

# %%
# %cd $root_dir/BasicSR/
# !python setup.py develop
# Out:
# /content/BasicSR
# running develop
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running egg_info
# creating basicsr.egg-info
# writing basicsr.egg-info/PKG-INFO
# writing dependency_links to basicsr.egg-info/dependency_links.txt
# writing requirements to basicsr.egg-info/requires.txt
# writing top-level names to basicsr.egg-info/top_level.txt
# writing manifest file 'basicsr.egg-info/SOURCES.txt'
# reading manifest file 'basicsr.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE.txt'
# writing manifest file 'basicsr.egg-info/SOURCES.txt'
# running build_ext
# ...

# %%
# %cd $root_dir/BBCU/BBCU-SR
# !python setup.py develop
# Out:
# /content/BBCU/BBCU-SR
# running develop
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running egg_info
# creating bbcu.egg-info
# writing bbcu.egg-info/PKG-INFO
# writing dependency_links to bbcu.egg-info/dependency_links.txt
# writing requirements to bbcu.egg-info/requires.txt
# writing top-level names to bbcu.egg-info/top_level.txt
# writing manifest file 'bbcu.egg-info/SOURCES.txt'
# reading manifest file 'bbcu.egg-info/SOURCES.txt'
# adding license file 'LICENSE.txt'
# writing manifest file 'bbcu.egg-info/SOURCES.txt'
# ...

# %%
# %cp -rf $source_dir/test_BBCUM_x2.yml $root_dir/BBCU/BBCU-SR/options/test/test_BBCUM_x2.yml
# %cp -rf $source_dir/train_BBCUM_x2.yml $root_dir/BBCU/BBCU-SR/options/train/train_BBCUM_x2.yml
# %cp -rf $source_dir/extract_subimages.py $root_dir/BBCU/BBCU-SR/scripts/data_preparation/extract_subimages.py

# %%
# %cd $root_dir
# Out:
# /content

# %%
# %mkdir div2k

# %%
# !unzip -q $source_dir/DIV2K_train_HR.zip -d div2k
# !unzip -q $source_dir/DIV2K_train_LR_bicubic_X2.zip -d div2k
# !tar -xf $source_dir/benchmark.tar -C $root_dir

# %%
# %mkdir $root_dir/BBCU/BBCU-SR/datasets/DIV2K

# %%
# !ln -s $root_dir/div2k/* $root_dir/BBCU/BBCU-SR/datasets/DIV2K
# !ln -s $root_dir/benchmark $root_dir/BBCU/BBCU-SR/datasets

# %%
# %cd $root_dir/BBCU/BBCU-SR
# !python scripts/data_preparation/extract_subimages.py
# Out:
# /content/BBCU/BBCU-SR
# mkdir datasets/DIV2K/DIV2K_train_HR_sub ...
# Extract: 100% 800/800 [17:09<00:00,  1.29s/image]
# All processes done.
# mkdir datasets/DIV2K/DIV2K_train_LR_bicubic/X2_sub ...
# Extract: 100% 800/800 [04:21<00:00,  3.06image/s]
# All processes done.

# %%
# !python $root_dir/BBCU/BBCU-SR/bbcu/train.py -opt $root_dir/BBCU/BBCU-SR/options/train/train_BBCUM_x2.yml
# Out:
# Disable distributed.
# 2023-03-15 20:52:15,553 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 1.13.1+cu116
# 	TorchVision: 0.14.1+cu116
# 2023-03-15 20:52:15,553 INFO:
#   name: Train_BBCUM_x2
#   model_type: SRModel
#   scale: 2
#   num_gpu: 1
#   manual_seed: 0
#   datasets:[
#     train:[
#       name: DIV2K
#       type: PairedImageDataset
# ...

# %%
# !python $root_dir/BBCU/BBCU-SR/bbcu/test.py -opt $root_dir/BBCU/BBCU-SR/options/test/test_BBCUM_x2.yml
# Out:
# Disable distributed.
# 2023-03-15 22:32:34,677 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 1.13.1+cu116
# 	TorchVision: 0.14.1+cu116
# 2023-03-15 22:32:34,677 INFO:
#   name: Test_BBCUM_x2
#   model_type: SRModel
#   scale: 2
#   num_gpu: 1
#   manual_seed: 0
#   datasets:[
#     test_1:[
#       name: Set5
#       type: PairedImageDataset
# ...
